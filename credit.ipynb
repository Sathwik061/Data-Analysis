# %% [markdown]
# #DATA ANALYSIS

# %%
import pandas as pd
df=pd.read_csv("C:/Users/madire sathwik/OneDrive/Desktop/data analysis/german_credit_cleaned.csv")
df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   checking_acc_status       1000 non-null   object
#  1   duration                  1000 non-null   int64
#  2   cred_hist                 1000 non-null   object
#  3   purpose                   1000 non-null   object
#  4   loan_amt                  1000 non-null   int64
#  5   saving_acc_bonds          1000 non-null   object
#  6   present_employment_since  1000 non-null   object
#  7   installment_rate          1000 non-null   int64
#  8   personal_stat_gender      1000 non-null   object
#  9   other_debtors_guarantors  1000 non-null   object
#  10  present_residence_since   1000 non-null   int64
#  11  property                  1000 non-null   object
#  12  age                       1000 non-null   int64
# ...

# %%
df.isnull()
# Out:
#      checking_acc_status  duration  cred_hist  purpose  loan_amt  \
# 0                  False     False      False    False     False
# 1                  False     False      False    False     False
# 2                  False     False      False    False     False
# 3                  False     False      False    False     False
# 4                  False     False      False    False     False
# ..                   ...       ...        ...      ...       ...
# 995                False     False      False    False     False
# 996                False     False      False    False     False
# 997                False     False      False    False     False
# 998                False     False      False    False     False
# 999                False     False      False    False     False
#
#      saving_acc_bonds  present_employment_since  installment_rate  \
# 0               False                     False             False
# ...

# %%
df['loan_amt'].mean()
# Out:
# 3271.258

# %%
df['age'].mode()
# Out:
# 0    27
# Name: age, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['checking_acc_status', 'duration', 'cred_hist', 'purpose', 'loan_amt',
#        'saving_acc_bonds', 'present_employment_since', 'installment_rate',
#        'personal_stat_gender', 'other_debtors_guarantors',
#        'present_residence_since', 'property', 'age', 'other_installment_plans',
#        'housing', 'num_curr_loans', 'job', 'num_people_provide_maint',
#        'telephone', 'is_foreign_worker', 'target'],
#       dtype='object')

# %%
n_df = df[['duration','loan_amt','installment_rate','present_residence_since','age', 'num_curr_loans', 'num_people_provide_maint']]
corr_matrix = n_df.corr()

plt.figure(figsize=(8, 6))  # Set the figure size
sns.heatmap(corr_matrix, annot=True, linewidths=0.5, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
corr_matrix = n_df.corr()
corr_matrix
# Out:
#                           duration  loan_amt  installment_rate  \
# duration                  1.000000  0.624984          0.074749
# loan_amt                  0.624984  1.000000         -0.271316
# installment_rate          0.074749 -0.271316          1.000000
# present_residence_since   0.034067  0.028926          0.049302
# age                      -0.036136  0.032716          0.058266
# num_curr_loans           -0.011284  0.020795          0.021669
# num_people_provide_maint -0.023834  0.017142         -0.071207
#
#                           present_residence_since       age  num_curr_loans  \
# duration                                 0.034067 -0.036136       -0.011284
# loan_amt                                 0.028926  0.032716        0.020795
# installment_rate                         0.049302  0.058266        0.021669
# present_residence_since                  1.000000  0.266419        0.089625
# age                                      0.266419  1.000000        0.149254
# ...

# %%
columns_to_drop = ['telephone', 'is_foreign_worker']
df = df.drop(columns=columns_to_drop)

# %%
df.columns
# Out:
# Index(['checking_acc_status', 'duration', 'cred_hist', 'purpose', 'loan_amt',
#        'saving_acc_bonds', 'present_employment_since', 'installment_rate',
#        'personal_stat_gender', 'other_debtors_guarantors',
#        'present_residence_since', 'property', 'age', 'other_installment_plans',
#        'housing', 'num_curr_loans', 'job', 'num_people_provide_maint',
#        'target'],
#       dtype='object')
